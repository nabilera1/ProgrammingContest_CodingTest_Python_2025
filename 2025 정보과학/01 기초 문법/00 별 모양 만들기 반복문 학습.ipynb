# %%
print(*['*' for _ in range(5)])
print(['*' for _ in range(5)])
for i in range(5):
    print('*', end='')
print() # 없으면?
print('*' * 10)

for i in range(5):
    print('*')

# %%
for i in range(3):
    print('*' * (i+1))
for i in range(3,0,-1):
    print('*' * (i))


for i in range(4, 0, -1):
    print(' ' * i, end='')
