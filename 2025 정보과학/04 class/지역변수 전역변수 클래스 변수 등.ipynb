# %%
def global_val():
    # global d
    d=d+1
    print(f'd={d}')

global_val()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3     d=d+1
#       4     print(f'd={d}')
# ----> 6 global_val()
#
# Cell In[1], line 3, in global_val()
#       1 def global_val():
#       2     # global d
# ----> 3     d=d+1
#       4     print(f'd={d}')
#
# UnboundLocalError: cannot access local variable 'd' where it is not associated with a value

# %%
d  = 10 # 전역변수
def global_val():
    global d
    d=d+1
    print(f'd={d}')

global_val()
# Out:
# d=11

# %%
# d  = 10 # 전역변수
def global_val1():
    global e
    e=e+1
    print(f'e={e}')

global_val1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4     e=e+1
#       5     print(f'e={e}')
# ----> 7 global_val1()
#
# Cell In[4], line 4, in global_val1()
#       2 def global_val1():
#       3     global e
# ----> 4     e=e+1
#       5     print(f'e={e}')
#
# NameError: name 'e' is not defined

# %%
전역변수, 지역변수



# 지역변수
def local_val():
   d  = 10
   print(f'd={d}')


local_val()


d  = 10 # 전역변수
def global_val():
   print(f'd={d}')


global_val()
print(d)


d  = 10 # 전역변수
def global_val():
   # global d
   d = 0
   d=d+1
   print(f'd={d}')


global_val() # d=1


d  = 10 # 전역변수
def global_val():
   global d
   d=d+1
   print(f'd={d}')


global_val()# d=11
