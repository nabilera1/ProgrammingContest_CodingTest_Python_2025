# %% [markdown]
# 🎲 random 모듈 핵심 요약 실습
# 학습 목표:
#
# random(): 0.0 ~ 1.0 사이 실수 생성
#
# randint(a, b): a부터 b까지 정수 생성 (주사위)
#
# choice(seq): 리스트에서 하나 무작위 선택 (제비뽑기)
#
# sample(seq, n): 리스트에서 n개 중복 없이 선택 (로또)
#
# shuffle(seq): 리스트 순서 섞기 (카드 섞기)

# %%
import random

# 1. 실수 생성 (0.0 <= x < 1.0)
print(f"1. 랜덤 실수: {random.random():.4f}")

# 2. 정수 생성 (1부터 100 사이)
dice = random.randint(1, 100)
print(f"2. 행운의 숫자: {dice}")

# 3. 하나만 선택 (가위바위보)
options = ['가위', '바위', '보']
computer = random.choice(options)
print(f"3. 컴퓨터 선택: {computer}")

# 4. 여러 개 선택 (중복 없음, 로또 번호 추천)
# range(1, 46)은 1부터 45까지의 숫자 범위
lotto = random.sample(range(1, 46), 6)
print(f"4. 로또 번호: {sorted(lotto)}")

# 5. 순서 섞기 (데이터 원본이 바뀜)
students = ["철수", "영희", "민수", "지수"]
random.shuffle(students)
print(f"5. 발표 순서: {students}")

# %%
1. 랜덤 실수: 0.7321
2. 행운의 숫자: 42
3. 컴퓨터 선택: 바위
4. 로또 번호: [3, 12, 25, 33, 38, 41]
5. 발표 순서: ['지수', '철수', '민수', '영희']

# %% [markdown]
# # 추가 학습자료
# https://docs.google.com/document/d/1ziyDyQc3cnh0GnXmSpUenit-Ir-aOfbq5Jx3wSdd7qY/edit?tab=t.0

# %%
import random

# 0 이상 100 미만에서 5의 배수만(상한 배제)
nums = [random.randrange(0, 100, 5) for _ in range(10)]
print("randrange multiples of 5:", nums)

# 16비트 무작위 정수(0 ~ 2^16-1)
r = random.getrandbits(16)
print("16-bit random int:", r)
# Out:
# randrange multiples of 5: [10, 70, 75, 15, 95, 65, 10, 40, 80, 35]
# 16-bit random int: 41811
