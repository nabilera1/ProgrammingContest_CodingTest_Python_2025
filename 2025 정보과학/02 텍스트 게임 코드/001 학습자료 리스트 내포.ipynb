# %% [markdown]
# # 🐍 파이썬 리스트 내포(List Comprehension) 완전 정복
#
# **학습 목표:** 파이썬의 꽃이라 불리는 리스트 내포 문법을 이해하고, 다양한 패턴의 실습 문제를 통해 완전히 내 것으로 만듭니다.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. 핵심 개념 요약
#
# ### 기본 문법
# > `[표현식 for 항목 in 반복가능객체]`
#
# ### 조건 필터링 (if)
# > `[표현식 for 항목 in 반복가능객체 if 조건]`
#
# ### 조건부 값 할당 (if-else)
# > `[참값 if 조건 else 거짓값 for 항목 in 반복가능객체]`

# %%
# [예제] 개념 확인하기
# 0부터 4까지 숫자의 제곱을 구하는 리스트

squares = [x**2 for x in range(5)]
print(f"결과: {squares}")

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 실습 문제 (총 10문제)
# 아래의 `# TODO` 부분을 지우고 직접 코드를 작성해서 실행해보세요.

# %% [markdown]
# ### Q1. 기본 문법 변환
# 다음 `for` 반복문 코드를 리스트 내포를 사용하여 **한 줄**로 작성하세요.
#
# ```python
# numbers = []
# for i in range(5):
#     numbers.append(i * 2)
# ```

# %%
# 정답을 작성하세요
q1_answer = [] 

print(q1_answer)

# %% [markdown]
# ### Q2. 3의 배수만 골라내기
# `range(10)` (0부터 9까지) 중에서 **3의 배수**만 리스트에 담으세요. (0 포함)
# * 힌트: `if x % 3 == 0`

# %%
# 정답을 작성하세요
q2_answer = []

print(q2_answer)

# %% [markdown]
# ### Q3. 긴 단어 찾기
# 아래 리스트에서 **글자 수가 4 이상**인 단어만 추출하세요.
# ```python
# words = ['apple', 'bat', 'cat', 'banana', 'dog']
# ```

# %%
words = ['apple', 'bat', 'cat', 'banana', 'dog']

# 정답을 작성하세요
q3_answer = []

print(q3_answer)

# %% [markdown]
# ### Q4. 짝수와 홀수 라벨링 (if-else)
# `range(3)`의 숫자에 대해, 짝수면 `'짝수'`, 홀수면 `'홀수'`라고 변환하여 리스트를 만드세요.
# * 목표 결과: `['짝수', '홀수', '짝수']`

# %%
# 정답을 작성하세요
q4_answer = []

print(q4_answer)

# %% [markdown]
# ### Q5. 2차원 리스트 펼치기 (Flatten)
# 중첩 리스트 `[[1, 2], [3, 4]]`를 `[1, 2, 3, 4]`로 만드세요.

# %%
matrix = [[1, 2], [3, 4]]

# 정답을 작성하세요
q5_answer = []

print(q5_answer)

# %% [markdown]
# ### Q6. 구구단 2단 (짝수 결과만)
# 1부터 9까지의 숫자 중, **짝수**에만 2를 곱해서 리스트를 만드세요.
# * 목표 결과: `[4, 8, 12, 16]` (2*2, 4*2, 6*2, 8*2)

# %%
# 정답을 작성하세요
q6_answer = []

print(q6_answer)

# %% [markdown]
# ### Q7. 모든 조합 만들기 (Cartesian Product)
# 문자열 `'AB'`와 `'12'`를 조합하여 `['A1', 'A2', 'B1', 'B2']`를 만드세요.

# %%
# 정답을 작성하세요
q7_answer = []

print(q7_answer)

# %% [markdown]
# ### Q8. 딕셔너리 키-값 뒤집기
# 주어진 딕셔너리의 키와 값을 서로 바꾸어 새로운 딕셔너리를 만드세요.
# * `d = {1: 'a', 2: 'b'}` -> `{'a': 1, 'b': 2}`

# %%
d = {1: 'a', 2: 'b'}

# 정답을 작성하세요 (01 딕셔너리 내포 사용)
q8_answer = {}

print(q8_answer)

# %% [markdown]
# ### Q9. 오류 수정하기
# 아래 코드는 `SyntaxError`가 발생합니다. `x`가 2보다 크면 `x`를, 아니면 `0`을 저장하도록 코드를 올바르게 수정하세요.
#
# ```python
# # 오류 코드
# [x for x in range(5) if x > 2 else 0]
# ```

# %%
# 올바르게 수정된 코드
q9_answer = []

print(q9_answer)

# %% [markdown]
# ### Q10. (서술형) 리스트 내포 사용 시 주의점
# 리스트 내포를 사용할 때 '너무 복잡한 로직'을 한 줄에 적으면 어떤 문제가 발생하나요?

# %%
# 여기에 생각난 답을 주석으로 적어보세요.
# 
#

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ 정답 코드 확인
# 문제를 다 푼 후 아래 코드를 확인하세요.

# %%
# Q1
print("Q1:", [i * 2 for i in range(5)])

# Q2
print("Q2:", [x for x in range(10) if x % 3 == 0])

# Q3
print("Q3:", [word for word in words if len(word) >= 4])

# Q4
print("Q4:", ['짝수' if i % 2 == 0 else '홀수' for i in range(3)])

# Q5
print("Q5:", [num for row in matrix for num in row])

# Q6
print("Q6:", [i * 2 for i in range(1, 10) if i % 2 == 0])

# Q7
print("Q7:", [x + y for x in 'AB' for y in '12'])

# Q8
print("Q8:", {v: k for k, v in d.items()})

# Q9
print("Q9:", [x if x > 2 else 0 for x in range(5)])

# Q10
# 답: 가독성이 떨어져서 코드를 이해하기 어려워집니다.
